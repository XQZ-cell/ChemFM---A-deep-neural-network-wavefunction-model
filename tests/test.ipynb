# %%
# %run /home/yinchang/ChemFM/run.py
# Out:
# [2025-12-16 16:13:40,964 - root - INFO] batch_size: 256
# config_module: src.config.base_config
# debug:
#   check_nan: false
#   deterministic: false
# log:
#   features: false
#   local_energies: false
#   max_to_keep: 10
#   restore_path: ''
#   save_interval_steps: 100
#   save_path: /home/yinchang/ChemFM/checkpoints
#   show_det_weights: false
#   stats_frequency: 1
#   walkers: false
# mcmc:
#   adapt_frequency: 100
#   blocks: 1
#   burn_in: 100
#   init_means: !!python/tuple []
#   init_width: 1.0
#   max_norm: 5.0
#   move_width: 0.02
#   num_leapfrog_steps: 10
#   proposal: random_walk
#   scale_by_nuclear_distance: false
#   steps: 30
# mode: training
# network:
#   bias_orbitals: false
#   complex: false
#   determinants: 16
#   ferminet:
#     electron_nuclear_aux_dims: !!python/tuple []
#     hidden_dims: !!python/tuple
#     - &id001 !!python/tuple
#       - 256
#       - 32
#     - *id001
#     - *id001
#     - *id001
#     nuclear_embedding_dim: 0
# ...
